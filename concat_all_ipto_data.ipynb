# %% [markdown]
# <a href="https://colab.research.google.com/github/ElenaNtm/IPTO-Data-projections/blob/main/concat_all_ipto_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Libraries

# %%
import pandas as pd
#import requests
from datetime import datetime, timedelta
#from datetime import datetime, timedelta
from urllib.error import HTTPError

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %% [markdown]
# #Upload all csv from drive

# %%
df_2018 = pd.read_csv('/content/drive/MyDrive/data_from2018.csv', parse_dates=['Date'], index_col='Date')

# %%
df_2018.head()
# Out:
#             Unnamed: 0  Total Gas  Total RES  Total Hydro  \
# Date
# 2018-01-01           0      28292      11706         6063
# 2018-01-02           1      34403      19014         6701
# 2018-01-03           2      39057      12966         6839
# 2018-01-04           3      45362      21505         9021
# 2018-01-05           4      48109       7269         8324
#
#             Total Lignite in MWh  Total Net Load  Exports - Imports
# Date
# 2018-01-01                 42864          116396           -29632.0
# 2018-01-02                 42972          126445           -24058.0
# 2018-01-03                 48943          136125           -28320.0
# 2018-01-04                 52584          149877           -23022.0
# 2018-01-05                 52834          144209           -28956.0

# %% [markdown]
# ##Gas

# %%
gas_2020 = pd.read_csv('/content/drive/MyDrive/gas_2020.csv', parse_dates=['Unnamed: 0'], index_col='Unnamed: 0')

# %%
gas_2020 = gas_2020.rename_axis('Date')

# %%
gas_2021 = pd.read_csv('/content/drive/MyDrive/gas_2021.csv', parse_dates=['Unnamed: 0'], index_col='Unnamed: 0')
gas_2021 = gas_2021.rename_axis('Date')

# %%
gas_2022 = pd.read_csv('/content/drive/MyDrive/gas_2022.csv', parse_dates=['Unnamed: 0'], index_col='Unnamed: 0')
gas_2022 = gas_2022.rename_axis('Date')

# %%
gas_2023 = pd.read_csv('/content/drive/MyDrive/gas_2023.csv', parse_dates=['Unnamed: 0'], index_col='Unnamed: 0')
gas_2023 = gas_2023.rename_axis('Date')

# %% [markdown]
# ##Hydro

# %%
hydro_2020 = pd.read_csv('/content/drive/MyDrive/hydro_2020.csv', parse_dates=['Unnamed: 0'], index_col='Unnamed: 0')
hydro_2020 = hydro_2020.rename_axis('Date')

# %%
hydro_2021 = pd.read_csv('/content/drive/MyDrive/hydro_2021.csv', parse_dates=['Unnamed: 0'], index_col='Unnamed: 0')
hydro_2021 = hydro_2021.rename_axis('Date')

# %%
hydro_2022 = pd.read_csv('/content/drive/MyDrive/hydro_2022.csv', parse_dates=['Unnamed: 0'], index_col='Unnamed: 0')
hydro_2022 = hydro_2022.rename_axis('Date')

# %%
hydro_2023 = pd.read_csv('/content/drive/MyDrive/hydro_2023.csv', parse_dates=['Unnamed: 0'], index_col='Unnamed: 0')
hydro_2023 = hydro_2023.rename_axis('Date')

# %% [markdown]
# ##Interconnections

# %%
inter_2020 = pd.read_csv('/content/drive/MyDrive/inter_2020.csv', parse_dates=['Unnamed: 0'], index_col='Unnamed: 0')
inter_2020 = inter_2020.rename_axis('Date')

# %%
inter_2021 = pd.read_csv('/content/drive/MyDrive/inter_2021.csv', parse_dates=['Unnamed: 0'], index_col='Unnamed: 0')
inter_2021 = inter_2021.rename_axis('Date')

# %%
inter_2022 = pd.read_csv('/content/drive/MyDrive/inter_2022.csv', parse_dates=['Unnamed: 0'], index_col='Unnamed: 0')
inter_2022 = inter_2022.rename_axis('Date')

# %%
inter_2023 = pd.read_csv('/content/drive/MyDrive/inter_2023.csv', parse_dates=['Unnamed: 0'], index_col='Unnamed: 0')
inter_2023 = inter_2023.rename_axis('Date')

# %%
inter_2023.head()
# Out:
#             Exports - Imports
# Date
# 2023-01-01             -39986
# 2023-01-02             -45057
# 2023-01-03             -45883
# 2023-01-04             -36985
# 2023-01-05             -43722

# %% [markdown]
# ##Lignite

# %%
lignite_2020 = pd.read_csv('/content/drive/MyDrive/lignite_2020.csv', parse_dates=['Unnamed: 0'], index_col='Unnamed: 0')
lignite_2020 = lignite_2020.rename_axis('Date')

# %%
lignite_2021 = pd.read_csv('/content/drive/MyDrive/lignite_2021.csv', parse_dates=['Unnamed: 0'], index_col='Unnamed: 0')
lignite_2021 = lignite_2021.rename_axis('Date')

# %%
lignite_2022 = pd.read_csv('/content/drive/MyDrive/lignite_2022.csv', parse_dates=['Unnamed: 0'], index_col='Unnamed: 0')
lignite_2022 = lignite_2022.rename_axis('Date')

# %%
lignite_2023 = pd.read_csv('/content/drive/MyDrive/lignite_2023.csv', parse_dates=['Unnamed: 0'], index_col='Unnamed: 0')
lignite_2023 = lignite_2023.rename_axis('Date')

# %%
net_load_2020 = pd.read_csv('/content/drive/MyDrive/net_load_2020.csv', parse_dates=['Unnamed: 0'], index_col='Unnamed: 0')
net_load_2020 = net_load_2020.rename_axis('Date')

# %%
net_load_2021 = pd.read_csv('/content/drive/MyDrive/net_load_2021.csv', parse_dates=['Unnamed: 0'], index_col='Unnamed: 0')
net_load_2021 = net_load_2021.rename_axis('Date')

# %%
net_load_2022 = pd.read_csv('/content/drive/MyDrive/net_load_2022.csv', parse_dates=['Unnamed: 0'], index_col='Unnamed: 0')
net_load_2022 = net_load_2022.rename_axis('Date')

# %%
net_load_2023 = pd.read_csv('/content/drive/MyDrive/net_load_2023.csv', parse_dates=['Unnamed: 0'], index_col='Unnamed: 0')
net_load_2023 = net_load_2023.rename_axis('Date')

# %%
res_2020 = pd.read_csv('/content/drive/MyDrive/res_2020.csv', parse_dates=['Unnamed: 0'], index_col='Unnamed: 0')
res_2020 = res_2020.rename_axis('Date')

# %%
res_2021 = pd.read_csv('/content/drive/MyDrive/res_2021.csv', parse_dates=['Unnamed: 0'], index_col='Unnamed: 0')
res_2021 = res_2021.rename_axis('Date')

# %%
res_2022 = pd.read_csv('/content/drive/MyDrive/res_2022.csv', parse_dates=['Unnamed: 0'], index_col='Unnamed: 0')
res_2022 = res_2022.rename_axis('Date')

# %%
res_2023 = pd.read_csv('/content/drive/MyDrive/res_2023.csv', parse_dates=['Unnamed: 0'], index_col='Unnamed: 0')
res_2023 = res_2023.rename_axis('Date')

# %% [markdown]
# #Concat the data by source

# %% [markdown]
# ##RES

# %%
df_res = pd.concat([res_2020, res_2021], axis = 0 )

# %%
df_res = pd.concat([df_res, res_2022], axis = 0 )

# %%
df_res = pd.concat([df_res, res_2023], axis = 0 )
df_res.head()
# Out:
#             Total RES
# Date
# 2020-06-01       6306
# 2020-06-02       7556
# 2020-06-03       7227
# 2020-06-04      12474
# 2020-06-05      27342

# %% [markdown]
# ##Gas

# %%
df_gas = pd.concat([gas_2020, gas_2021], axis = 0 )

# %%
df_gas = pd.concat([df_gas, gas_2022], axis = 0 )

# %%
df_gas = pd.concat([df_gas, gas_2023], axis = 0 )

# %% [markdown]
# ##Lignite

# %%
df_lignite = pd.concat([lignite_2020, lignite_2021], axis = 0)

# %%
df_lignite = pd.concat([df_lignite, lignite_2022], axis = 0)

# %%
df_lignite = pd.concat([df_lignite, lignite_2023], axis = 0)

# %% [markdown]
# ##Net Load

# %%
df_net_load = pd.concat([net_load_2020, net_load_2021], axis = 0)

# %%
df_net_load = pd.concat([df_net_load, net_load_2022], axis = 0)

# %%
df_net_load = pd.concat([df_net_load, net_load_2023], axis = 0)

# %% [markdown]
# ##Hydro

# %%
df_hydro = pd.concat([hydro_2020, hydro_2021], axis = 0)

# %%
df_hydro = pd.concat([df_hydro, hydro_2022], axis = 0)

# %%
df_hydro = pd.concat([df_hydro, hydro_2023], axis = 0)

# %% [markdown]
# ##Interconnections

# %%
df_inter = pd.concat([inter_2020, inter_2021], axis = 0)

# %%
df_inter = pd.concat([df_inter, inter_2022], axis = 0)

# %%
df_inter = pd.concat([df_inter, inter_2023], axis = 0)

# %%
df_inter.head()
# Out:
#             Exports - Imports
# Date
# 2020-06-01             -33358
# 2020-06-02             -23170
# 2020-06-03             -19802
# 2020-06-04             -19880
# 2020-06-05             -20686

# %% [markdown]
# #Rename the columns in the old data

# %%
df_2018 = df_2018.drop('Unnamed: 0', axis =1)

# %%
df_2018.rename(columns = {'Total Lignite in MWh': 'Total Lignite'}, inplace = True)

# %%
df_lignite.rename(columns = {'Total Lignite in MWh': 'Total Lignite'}, inplace = True)

# %%
df_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 805 entries, 2018-01-01 to 2020-07-30
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Total Gas          805 non-null    int64
#  1   Total RES          805 non-null    int64
#  2   Total Hydro        805 non-null    int64
#  3   Total Lignite      805 non-null    int64
#  4   Total Net Load     805 non-null    int64
#  5   Exports - Imports  798 non-null    float64
# dtypes: float64(1), int64(5)
# memory usage: 44.0 KB

# %% [markdown]
# #Concat all the data to one dataframe

# %%
data = pd.concat([df_lignite, df_res], axis =1)
data.tail()
# Out:
#             Total Lignite  Total RES
# Date
# 2023-05-31           3672      13026
# 2023-06-30           5227      11699
# 2023-07-31           8217      20742
# 2023-08-31          12563      29966
# 2023-09-30              0      27832

# %%
data = pd.concat([data, df_gas], axis =1 )
data.tail()
# Out:
#             Total Lignite  Total RES  Total Gas
# Date
# 2023-05-31           3672      13026      40648
# 2023-06-30           5227      11699      74351
# 2023-07-31           8217      20742      69123
# 2023-08-31          12563      29966      59411
# 2023-09-30              0      27832      46316

# %%
data = pd.concat([data, df_inter], axis = 1)
data.tail()
# Out:
#             Total Lignite  Total RES  Total Gas  Exports - Imports
# Date
# 2023-05-31           3672      13026      40648             -27315
# 2023-06-30           5227      11699      74351              -8990
# 2023-07-31           8217      20742      69123             -28446
# 2023-08-31          12563      29966      59411              -9862
# 2023-09-30              0      27832      46316              -3735

# %%
data = pd.concat([data, df_hydro], axis = 1)
data.tail()
# Out:
#             Total Lignite  Total RES  Total Gas  Exports - Imports  \
# Date
# 2023-05-31           3672      13026      40648             -27315
# 2023-06-30           5227      11699      74351              -8990
# 2023-07-31           8217      20742      69123             -28446
# 2023-08-31          12563      29966      59411              -9862
# 2023-09-30              0      27832      46316              -3735
#
#             Total Hydro
# Date
# 2023-05-31        10989
# 2023-06-30        13806
# 2023-07-31        14763
# 2023-08-31        11620
# 2023-09-30        12295

# %%
data = pd.concat([data, df_net_load], axis = 1)
data.tail()
# Out:
#             Total Lignite  Total RES  Total Gas  Exports - Imports  \
# Date
# 2023-05-31           3672      13026      40648             -27315
# 2023-06-30           5227      11699      74351              -8990
# 2023-07-31           8217      20742      69123             -28446
# 2023-08-31          12563      29966      59411              -9862
# 2023-09-30              0      27832      46316              -3735
#
#             Total Hydro  Total Net Load
# Date
# 2023-05-31        10989           92872
# 2023-06-30        13806          111572
# 2023-07-31        14763          138428
# 2023-08-31        11620          120440
# 2023-09-30        12295           86841

# %%
data = pd.concat([df_2018,data], axis = 0)
data.tail()
# Out:
#             Total Gas  Total RES  Total Hydro  Total Lignite  Total Net Load  \
# Date
# 2023-05-31      40648      13026        10989           3672           92872
# 2023-06-30      74351      11699        13806           5227          111572
# 2023-07-31      69123      20742        14763           8217          138428
# 2023-08-31      59411      29966        11620          12563          120440
# 2023-09-30      46316      27832        12295              0           86841
#
#             Exports - Imports
# Date
# 2023-05-31           -27315.0
# 2023-06-30            -8990.0
# 2023-07-31           -28446.0
# 2023-08-31            -9862.0
# 2023-09-30            -3735.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2050 entries, 2018-01-01 00:00:00 to 2023-09-30
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Total Gas          2050 non-null   int64
#  1   Total RES          2050 non-null   int64
#  2   Total Hydro        2050 non-null   int64
#  3   Total Lignite      2050 non-null   int64
#  4   Total Net Load     2050 non-null   int64
#  5   Exports - Imports  2043 non-null   float64
# dtypes: float64(1), int64(5)
# memory usage: 112.1+ KB

# %%
data.index = pd.to_datetime(data.index)

# %%
data = data.sort_index()
#data.dropna(axis = 1)
data.head()
# Out:
#             Total Gas  Total RES  Total Hydro  Total Lignite  Total Net Load  \
# Date
# 2018-01-01      28292      11706         6063          42864          116396
# 2018-01-02      34403      19014         6701          42972          126445
# 2018-01-03      39057      12966         6839          48943          136125
# 2018-01-04      45362      21505         9021          52584          149877
# 2018-01-05      48109       7269         8324          52834          144209
#
#             Exports - Imports
# Date
# 2018-01-01           -29632.0
# 2018-01-02           -24058.0
# 2018-01-03           -28320.0
# 2018-01-04           -23022.0
# 2018-01-05           -28956.0

# %% [markdown]
# #Save the new data

# %%
data.to_csv('data_complete.csv')
# !cp data_complete.csv "drive/My Drive/"
